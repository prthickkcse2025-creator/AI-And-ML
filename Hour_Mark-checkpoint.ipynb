# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("Hour_Mark.csv")
df.head()
# Out:
#    Hours   Marks
# 0       1       2
# 1       2       4
# 2       3       6
# 3       4       8
# 4       5      10

# %%
plt.scatter(df["Hours "],df["Marks "])
plt.xlabel("Hours")
plt.ylabel("Marks")
plt.show()

# %%
x=df[["Hours "]]
y=df["Marks "]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
x_train.shape
# Out:
# (75, 1)

# %%
x_test.shape
# Out:
# (25, 1)

# %%
from  sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_train
# Out:
# array([[-1.209608  ],
#        [-0.35536506],
#        [ 1.55813911],
#        [-1.4146263 ],
#        [ 0.7380659 ],
#        [-1.34628687],
#        [-0.11617704],
#        [ 1.18227222],
#        [-0.76540167],
#        [ 1.45562996],
#        [-1.55130517],
#        [ 0.53304759],
#        [ 0.49887787],
#        [-0.52621365],
#        [-1.17543828],
#        [-0.0478376 ],
#        [-0.56038337],
#        [-1.48296574],
#        [ 1.5239694 ],
#        [-0.79957139],
#        [-1.07292913],
#        [ 1.04559335],
#        [-0.86791082],
#        [ 0.39636872],
#        [-1.27794743],
#        [-0.90208054],
#        [-1.6196446 ],
#        [-1.14126856],
#        [-0.4237045 ],
#        [-1.44879602],
#        [ 0.9430842 ],
#        [-1.51713545],
#        [ 0.46470816],
#        [-0.49204393],
#        [ 1.31895109],
#        [ 0.19135042],
#        [ 1.66064827],
#        [ 0.12301098],
#        [-0.25285591],
#        [-0.01366789],
#        [ 0.56721731],
#        [-0.15034676],
#        [ 0.60138703],
#        [ 0.362199  ],
#        [ 1.59230883],
#        [ 0.97725392],
#        [-0.32119534],
#        [ 0.25968985],
#        [-0.08200732],
#        [ 1.62647855],
#        [ 0.22552013],
#        [ 0.84057505],
#        [-0.6287228 ],
#        [ 1.48979968],
#        [ 0.29385957],
#        [ 0.43053844],
#        [ 1.1481025 ],
#        [-0.45787421],
#        [-0.73123195],
#        [-1.68798404],
#        [ 0.05467155],
#        [-1.00458969],
#        [-1.65381432],
#        [-0.93625026],
#        [ 1.25061166],
#        [ 1.38729053],
#        [ 0.80640533],
#        [ 1.21644194],
#        [ 1.07976307],
#        [-1.03875941],
#        [ 0.32802929],
#        [ 0.70389618],
#        [-1.24377771],
#        [ 1.42146024],
#        [ 0.02050183]])

# %%
x_test=scaler.transform(x_test)
x_test
# Out:
# array([[ 1.11393279],
#        [ 0.08884127],
#        [ 0.66972646],
#        [-0.18451647],
#        [-0.21868619],
#        [-0.38953478],
#        [-0.97041997],
#        [ 1.01142364],
#        [-1.38045658],
#        [-1.72215376],
#        [-1.10709884],
#        [-0.69706223],
#        [ 0.77223561],
#        [-0.59455308],
#        [ 1.35312081],
#        [-1.58547489],
#        [ 0.87474477],
#        [ 0.90891448],
#        [-1.31211715],
#        [-0.66289252],
#        [ 0.1571807 ],
#        [ 1.28478137],
#        [-0.8337411 ],
#        [-0.28702563],
#        [ 0.63555674]])

# %%
plt.scatter(x_train,y_train)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
linear=LinearRegression()

# %%
linear.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
linear.coef_
# Out:
# array([58.53135912])

# %%
linear.intercept_
# Out:
# np.float64(102.8)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,linear.predict(x_train),'r')
plt.show()

# %%
y_pred=linear.predict(x_test)
y_pred
# Out:
# array([168., 108., 142.,  92.,  90.,  80.,  46., 162.,  22.,   2.,  38.,
#         62., 148.,  68., 182.,  10., 154., 156.,  26.,  64., 112., 178.,
#         54.,  86., 140.])

# %%
b=scaler.transform([[100]])
b
# Out:
# c:\Users\kukar\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[1.66064827]])

# %%
y_pred_1=linear.predict(b)
y_pred_1
# Out:
# array([200.])

# %%
c=scaler.transform([[3]])
c
# Out:
# c:\Users\kukar\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-1.65381432]])

# %%
y_pred_2=linear.predict(c)
y_pred_2
# Out:
# array([6.])
