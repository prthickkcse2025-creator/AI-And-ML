# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("Height_Weight.csv")
df.head()
# Out:
#    Height  Weight
# 0     150      48
# 1     152      70
# 2     154      52
# 3     156      54
# 4     158      56

# %%
plt.scatter(df["Weight"],df["Height"])
plt.xlabel("Weight")
plt.ylabel("Height")
plt.show()

# %%
x=df[["Weight"]]
y=df["Height"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
x.shape
# Out:
# (80, 1)

# %%
    y.shape
# Out:
# (80,)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)
x_train
# Out:
# array([[-8.38200772e-02],
#        [-1.15561779e+00],
#        [-7.43387898e-01],
#        [-5.78495943e-01],
#        [ 6.58193721e-01],
#        [-1.48540170e+00],
#        [-1.40295572e+00],
#        [ 5.75747743e-01],
#        [ 1.07042361e+00],
#        [ 1.48265350e+00],
#        [ 9.05531654e-01],
#        [ 1.31776154e+00],
#        [-4.13603988e-01],
#        [-8.38200772e-02],
#        [ 4.10855788e-01],
#        [ 1.56509947e+00],
#        [-8.25833875e-01],
#        [-8.25833875e-01],
#        [-1.07317181e+00],
#        [ 5.75747743e-01],
#        [ 8.23085676e-01],
#        [-1.07317181e+00],
#        [ 1.23531556e+00],
#        [ 1.31776154e+00],
#        [-2.48712032e-01],
#        [-9.90725831e-01],
#        [ 1.07042361e+00],
#        [ 9.87977631e-01],
#        [ 1.63517856e-01],
#        [ 1.23531556e+00],
#        [-7.43387898e-01],
#        [ 1.15286959e+00],
#        [ 9.05531654e-01],
#        [-4.96049965e-01],
#        [-1.56784767e+00],
#        [-6.60941920e-01],
#        [-4.13603988e-01],
#        [-9.90725831e-01],
#        [-1.23806376e+00],
#        [ 9.87977631e-01],
#        [ 1.07042361e+00],
#        [ 2.45963833e-01],
#        [ 3.28409811e-01],
#        [ 6.58193721e-01],
#        [ 1.40020752e+00],
#        [-1.32050974e+00],
#        [-3.31158010e-01],
#        [ 1.15286959e+00],
#        [-1.66266055e-01],
#        [ 2.45963833e-01],
#        [ 2.45963833e-01],
#        [-1.48540170e+00],
#        [-1.23806376e+00],
#        [-1.15561779e+00],
#        [ 4.93301766e-01],
#        [-1.65029365e+00],
#        [-1.81518561e+00],
#        [-1.37409963e-03],
#        [ 1.89488338e+00],
#        [ 8.10718780e-02]])

# %%
x_test=scaler.transform(x_test)
x_test
# Out:
# array([[-1.37409963e-03],
#        [-1.56784767e+00],
#        [-1.32050974e+00],
#        [ 1.63517856e-01],
#        [ 1.40020752e+00],
#        [-3.31158010e-01],
#        [ 8.10718780e-02],
#        [-1.66266055e-01],
#        [-9.08279853e-01],
#        [ 4.10855788e-01],
#        [-2.48712032e-01],
#        [ 4.93301766e-01],
#        [-6.60941920e-01],
#        [ 8.23085676e-01],
#        [-4.96049965e-01],
#        [-9.08279853e-01],
#        [ 3.28409811e-01],
#        [-1.65029365e+00],
#        [ 7.40639699e-01],
#        [-1.73273963e+00]])

# %%
plt.scatter(x_train,y_train)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
linear=LinearRegression()

# %%
linear.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print("Coefficient",linear.coef_)
# Out:
# Coefficient [11.24821923]

# %%
print("Intercept",linear.intercept_)
# Out:
# Intercept 168.11666666666667

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,linear.predict(x_train),'r')
plt.show()

# %%
y_pred=linear.predict(x_test)
y_pred
# Out:
# array([168.10121049, 150.48117231, 153.26328361, 169.95595135,
#        183.86650781, 164.39172877, 169.02858092, 166.24646963,
#        157.90013576, 172.73806265, 165.3190992 , 173.66543308,
#        160.68224705, 177.3749148 , 162.53698791, 157.90013576,
#        171.81069221, 149.55380188, 176.44754437, 148.62643145])

# %%
new=scaler.transform([[83]])
new
# Out:
# c:\Users\kukar\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[1.31776154]])

# %%
a=linear.predict(new)
a
# Out:
# array([182.93913738])

# %%
b=scaler.transform([[34]])
b
# Out:
# c:\Users\kukar\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-2.72209136]])

# %%
c=linear.predict(b)
c
# Out:
# array([137.49798629])

# %%
|
